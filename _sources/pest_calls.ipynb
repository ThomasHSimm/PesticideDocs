# %%
import pandas as pd


import sys
sys.path.append("..")

import src.data_loading.loads_from_url as lfu
import src.data_cleaning.modify_dfs as mdf
import src.data_visualisation.plot_funcs as pfs
import src.data_cleaning.modify_dfs as md
import src.utils.loads_from_url as utils

import re
import os
from pandasql import sqldf

import seaborn as sns
import matplotlib.pyplot as plt

# %%
cwd = os.getcwd()
cwd = re.split(r"[A-Za-z]+$",cwd)[0]

folder_path = os.path.join(cwd, 'data')

# %%
all_dfs = lfu.import_all_ods(folder_path)
# Out:
# Importing 2016_annual_data
# Failed to load 2016_annual_data: Apple_SUM
# Failed to load 2016_annual_data: Apricots_SUM
# Failed to load 2016_annual_data: Beans_with_pods_SUM_
# Failed to load 2016_annual_data: Bread_SUM
# Failed to load 2016_annual_data: Breakfast_Cereal_SUM
# Failed to load 2016_annual_data: Cabbage_SUM
# Failed to load 2016_annual_data: Cashew_nuts_SUM
# Failed to load 2016_annual_data: Cheese_processed_SUM
# Failed to load 2016_annual_data: Cooked_meat_SUM
# Failed to load 2016_annual_data: Fish_predator_SUM
# Failed to load 2016_annual_data: Fish_sea_SUM
# Failed to load 2016_annual_data: Gluten-free_food_SUM
# Failed to load 2016_annual_data: Grapefruit_SUM
# Failed to load 2016_annual_data: Grapes_SUM
# Failed to load 2016_annual_data: Honey_SUM
# Failed to load 2016_annual_data: Infant_food_SUM
# Failed to load 2016_annual_data: Jam_SUM
# Failed to load 2016_annual_data: Leeks_SUM
# Failed to load 2016_annual_data: Lettuce_SUM
# Failed to load 2016_annual_data: Milk-SUM
# Failed to load 2016_annual_data: Non-dairy_milk_SUM
# Failed to load 2016_annual_data: Okra_SUM
# Failed to load 2016_annual_data: Pasta_SUM
# Failed to load 2016_annual_data: PeachesNectarines_SUM
# Failed to load 2016_annual_data: Pears_SUM
# Failed to load 2016_annual_data: Peppers_SUM
# Failed to load 2016_annual_data: Popcorn_SUM
# Failed to load 2016_annual_data: Pork_SUM
# Failed to load 2016_annual_data: Pork_proc_SUM
# Failed to load 2016_annual_data: Potatoes_SUM
# Failed to load 2016_annual_data: Prepfruit_SUM
# Failed to load 2016_annual_data: Rye_SUM
# Failed to load 2016_annual_data: Ryeflour_SUM
# Failed to load 2016_annual_data: Specialityveg_SUM
# Failed to load 2016_annual_data: Spices_SUM
# Failed to load 2016_annual_data: Springonions_SUM
# Failed to load 2016_annual_data: Strawberries_SUM
# Failed to load 2016_annual_data: Tomatoes_SUM
# Failed to load 2016_annual_data: TinTomatoes_SUM
# Failed to load 2016_annual_data: Wine_SUM
# Importing 2017_annual_data
# Failed to load 2017_annual_data: Apple_SUM
# Failed to load 2017_annual_data: Beans_SUM
# Failed to load 2017_annual_data: Beans(tinned)_SUM
# Failed to load 2017_annual_data: Bread_SUM
# Failed to load 2017_annual_data: Carrots_SUM
# Failed to load 2017_annual_data: Cauliflower_SUM
# Failed to load 2017_annual_data: Cheese(hard)_SUM
# Failed to load 2017_annual_data: Cherry_SUM
# Failed to load 2017_annual_data: Cucumber_SUM
# Failed to load 2017_annual_data: Fish(oily)_SUM
# Failed to load 2017_annual_data: Grapes_SUM
# Failed to load 2017_annual_data: InfantFormula_SUM
# Failed to load 2017_annual_data: KiwiFruit_SUM
# Failed to load 2017_annual_data: Lamb_SUM
# Failed to load 2017_annual_data: Lemon&Limes_SUM
# Failed to load 2017_annual_data: Lettuce_SUM
# Failed to load 2017_annual_data: Milk_SUM
# Failed to load 2017_annual_data: Okra_SUM
# Failed to load 2017_annual_data: Onions_SUM
# Failed to load 2017_annual_data: Oranges_SUM
# Failed to load 2017_annual_data: Parsnip_SUM
# Failed to load 2017_annual_data: Pears_SUM
# Failed to load 2017_annual_data: Peppers_SUM
# Failed to load 2017_annual_data: Potato_SUM
# Failed to load 2017_annual_data: PoultryMeat_SUM
# Failed to load 2017_annual_data: Poultry(proc)_SUM
# Failed to load 2017_annual_data: PreparedFruit_SUM
# Failed to load 2017_annual_data: Raspberry_SUM
# Failed to load 2017_annual_data: Rice_SUM
# Failed to load 2017_annual_data: RyeFlour_SUM
# Failed to load 2017_annual_data: RyeGrain_SUM
# Failed to load 2017_annual_data: Shellfish_SUM
# Failed to load 2017_annual_data: SoyaMilk_SUM
# Failed to load 2017_annual_data: SoyaProd_SUM
# Failed to load 2017_annual_data: SpecBeans(dried)_SUM
# Failed to load 2017_annual_data: SpecFruit_SUM
# Failed to load 2017_annual_data: SprGreens&Kale_SUM
# Failed to load 2017_annual_data: Yogurt_SUM
# Importing 2018_annual_data
# Importing Apr_2022_rolling_report_v2
# Failed to load Apr_2022_rolling_report_v2: Summary
# Importing August_2022_rolling_reports
# Failed to load August_2022_rolling_reports: Summary
# Importing July_2022_rolling_reports
# Failed to load July_2022_rolling_reports: Summary
# Importing June_2022_rolling_reports
# Failed to load June_2022_rolling_reports: Summary
# Importing May_2022_rolling_report
# Failed to load May_2022_rolling_report: Summary
# Importing October_2022_rolling_reports
# Failed to load October_2022_rolling_reports: Summary
# Importing Q1_2018_quarterly_data
# Failed to load Q1_2018_quarterly_data: Introduction
# Failed to load Q1_2018_quarterly_data: Apple_SUM
# Failed to load Q1_2018_quarterly_data: Aubergine_SUM
# Failed to load Q1_2018_quarterly_data: Banana_SUM
# Failed to load Q1_2018_quarterly_data: Beans_SUM
# Failed to load Q1_2018_quarterly_data: Beef_SUM
# Failed to load Q1_2018_quarterly_data: Broccoli_SUM
# Failed to load Q1_2018_quarterly_data: Eggs_SUM
# Failed to load Q1_2018_quarterly_data: Fish(white)_SUM
# Failed to load Q1_2018_quarterly_data: Frozen_Veg_SUM
# Failed to load Q1_2018_quarterly_data: Game_SUM
# Failed to load Q1_2018_quarterly_data: Grapefruit_SUM
# Failed to load Q1_2018_quarterly_data: Grapes_SUM
# Failed to load Q1_2018_quarterly_data: Lettuce_SUM
# Failed to load Q1_2018_quarterly_data: Melon_SUM
# Failed to load Q1_2018_quarterly_data: Milk_SUM
# Failed to load Q1_2018_quarterly_data: Mushroom_SUM
# Failed to load Q1_2018_quarterly_data: Okra_SUM
# Failed to load Q1_2018_quarterly_data: Pears_SUM
# Failed to load Q1_2018_quarterly_data: Peppers_SUM
# Failed to load Q1_2018_quarterly_data: Pineapple_SUM
# Failed to load Q1_2018_quarterly_data: Potato_SUM
# Importing Q1_2019_quarterly_data
# Failed to load Q1_2019_quarterly_data: Introduction
# Failed to load Q1_2019_quarterly_data: Apples_SUM
# Failed to load Q1_2019_quarterly_data: Beans_with_pods_SUM
# Failed to load Q1_2019_quarterly_data: Cabbage_SUM
# Failed to load Q1_2019_quarterly_data: Chillies_SUM
# Failed to load Q1_2019_quarterly_data: Cooked_meats_SUM
# Failed to load Q1_2019_quarterly_data: Fish_SUM
# Failed to load Q1_2019_quarterly_data: Grapes_SUM
# Failed to load Q1_2019_quarterly_data: Lemons_SUM
# Failed to load Q1_2019_quarterly_data: Lettuce_SUM
# Failed to load Q1_2019_quarterly_data: Milk_SUM
# Failed to load Q1_2019_quarterly_data: Okra_SUM
# Failed to load Q1_2019_quarterly_data: Peach_&_Nectarines_SUM
# Failed to load Q1_2019_quarterly_data: Peppers_SUM
# Failed to load Q1_2019_quarterly_data: Pork_SUM
# Failed to load Q1_2019_quarterly_data: Potatoes_SUM
# Failed to load Q1_2019_quarterly_data: Rice_SUM
# Failed to load Q1_2019_quarterly_data: Shellfish_SUM
# Failed to load Q1_2019_quarterly_data: Spinach_SUM
# Failed to load Q1_2019_quarterly_data: Strawberries_SUM
# Failed to load Q1_2019_quarterly_data: Tomatoes_SUM
# Importing Q1_2020_quarterly_data
# Failed to load Q1_2020_quarterly_data: Introduction
# Failed to load Q1_2020_quarterly_data: Avocado_SUM
# Failed to load Q1_2020_quarterly_data: Beans_SUM
# Failed to load Q1_2020_quarterly_data: Carrots_SUM
# Failed to load Q1_2020_quarterly_data: Cauliflower_SUM
# Failed to load Q1_2020_quarterly_data: Fish(oily)_SUM
# Failed to load Q1_2020_quarterly_data: Grapes_SUM
# Failed to load Q1_2020_quarterly_data: Kiwi_SUM
# Failed to load Q1_2020_quarterly_data: Lamb_SUM
# Failed to load Q1_2020_quarterly_data: Lettuce_SUM
# Failed to load Q1_2020_quarterly_data: Liver_SUM
# Failed to load Q1_2020_quarterly_data: Mango_SUM
# Failed to load Q1_2020_quarterly_data: Milk_SUM
# Failed to load Q1_2020_quarterly_data: Okra_SUM
# Failed to load Q1_2020_quarterly_data: Onions_SUM
# Failed to load Q1_2020_quarterly_data: Oranges_SUM
# Failed to load Q1_2020_quarterly_data: Pate_SUM
# Failed to load Q1_2020_quarterly_data: Pears_SUM
# Failed to load Q1_2020_quarterly_data: Peas_SUM
# Failed to load Q1_2020_quarterly_data: Potato_SUM
# Failed to load Q1_2020_quarterly_data: Poultry_SUM
# Failed to load Q1_2020_quarterly_data: Rice_SUM
# Importing Q1_2021_quarterly_data
# Failed to load Q1_2021_quarterly_data: Summary
# Failed to load Q1_2021_quarterly_data: Aubergine_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Banana_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Beans_with_pods_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Beef_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Berries_and_small_fruits_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Broccoli_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Cheese_(Soft)_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Eggs_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Fish_(White)_Q1_NI_only_SUM
# Failed to load Q1_2021_quarterly_data: Grapes_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Melon_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Milk_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Mushrooms_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Peppers_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Potatoes_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Raspberries_Q1_SUM
# Failed to load Q1_2021_quarterly_data: Rice_Q1_SUM
# Importing Q2_2018_quarterly_data
# Failed to load Q2_2018_quarterly_data: Introduction
# Failed to load Q2_2018_quarterly_data: AnimalFats_SUM
# Failed to load Q2_2018_quarterly_data: Apple_SUM
# Failed to load Q2_2018_quarterly_data: Aubergine_SUM
# Failed to load Q2_2018_quarterly_data: Banana_SUM
# Failed to load Q2_2018_quarterly_data: Beans_SUM
# Failed to load Q2_2018_quarterly_data: Beef_SUM
# Failed to load Q2_2018_quarterly_data: Berries_SUM
# Failed to load Q2_2018_quarterly_data: Broccoli_SUM
# Failed to load Q2_2018_quarterly_data: CheeseSoft_SUM
# Failed to load Q2_2018_quarterly_data: ChineseCabbage_SUM
# Failed to load Q2_2018_quarterly_data: Cream_SUM
# Failed to load Q2_2018_quarterly_data: CurryLeaves_SUM
# Failed to load Q2_2018_quarterly_data: Eggs_SUM
# Failed to load Q2_2018_quarterly_data: FishWhite_SUM
# Failed to load Q2_2018_quarterly_data: Game_SUM
# Failed to load Q2_2018_quarterly_data: Grapefruit_SUM
# Failed to load Q2_2018_quarterly_data: Grapes_SUM
# Failed to load Q2_2018_quarterly_data: Lettuce_SUM
# Failed to load Q2_2018_quarterly_data: Melon_SUM
# Failed to load Q2_2018_quarterly_data: Milk_SUM
# Failed to load Q2_2018_quarterly_data: Mushrooms_SUM
# Failed to load Q2_2018_quarterly_data: MushroomSpeciality_SUM
# Failed to load Q2_2018_quarterly_data: Okra_SUM
# Failed to load Q2_2018_quarterly_data: Pears_SUM
# Failed to load Q2_2018_quarterly_data: Peas_SUM
# Failed to load Q2_2018_quarterly_data: Peppers_SUM
# Failed to load Q2_2018_quarterly_data: Pineapple_SUM
# Failed to load Q2_2018_quarterly_data: Potato_SUM
# Failed to load Q2_2018_quarterly_data: SoftCitrus_SUM
# Failed to load Q2_2018_quarterly_data: SpecVeg_SUM
# Importing Q2_2019_quarterly_data
# Failed to load Q2_2019_quarterly_data: Introduction
# Failed to load Q2_2019_quarterly_data: Apple_SUM
# Failed to load Q2_2019_quarterly_data: Barley_SUM
# Failed to load Q2_2019_quarterly_data: Beans_SUM
# Failed to load Q2_2019_quarterly_data: Butter_SUM
# Failed to load Q2_2019_quarterly_data: Cabbage_SUM
# Failed to load Q2_2019_quarterly_data: Cheese_SUM
# Failed to load Q2_2019_quarterly_data: Fish_SUM
# Failed to load Q2_2019_quarterly_data: Grapes_SUM
# Failed to load Q2_2019_quarterly_data: Honey_SUM
# Failed to load Q2_2019_quarterly_data: Lemons_SUM
# Failed to load Q2_2019_quarterly_data: Milk_SUM
# Failed to load Q2_2019_quarterly_data: Oats_SUM
# Failed to load Q2_2019_quarterly_data: Okra_SUM
# Failed to load Q2_2019_quarterly_data: Pasta_SUM
# Failed to load Q2_2019_quarterly_data: Peach&Nect_SUM
# Failed to load Q2_2019_quarterly_data: Peppers_SUM
# Failed to load Q2_2019_quarterly_data: Plums_SUM
# Failed to load Q2_2019_quarterly_data: Potato_SUM
# Failed to load Q2_2019_quarterly_data: PrePacked_Salad_SUM
# Failed to load Q2_2019_quarterly_data: Shellfish_SUM
# Failed to load Q2_2019_quarterly_data: Spinach_SUM
# Failed to load Q2_2019_quarterly_data: Strawberry_SUM
# Failed to load Q2_2019_quarterly_data: Tomato_SUM
# Failed to load Q2_2019_quarterly_data: Wine_SUM
# Importing Q2_2021_quarterly_data
# Failed to load Q2_2021_quarterly_data: Summary
# Failed to load Q2_2021_quarterly_data: Asparagus_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Aubergine_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Banana_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Beans_with_pods_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Beef_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Berries_and_small_fruits_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Broccoli_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Cheese_(Soft)_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Eggs_GB_Only_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Fish_(White)_Q2_NI_only_SUM
# Failed to load Q2_2021_quarterly_data: Grapefruit_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Grapes_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Melon_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Milk_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Mushrooms_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Olive_Oil_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Peppers_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Potatoes_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Raspberries_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Spring_Greens_Q2_SUM
# Failed to load Q2_2021_quarterly_data: Wheat_Q2_SUM
# Importing Q2_Q3_2020_Data
# Failed to load Q2_Q3_2020_Data: Introduction
# Failed to load Q2_Q3_2020_Data: Avocado_SUM_
# Failed to load Q2_Q3_2020_Data: Beans_(Dried)_Q2_SUM
# Failed to load Q2_Q3_2020_Data: Bread_SUM
# Failed to load Q2_Q3_2020_Data: Carrots_SUM
# Failed to load Q2_Q3_2020_Data: Cauliflower_SUM
# Failed to load Q2_Q3_2020_Data: Courgette_SUM
# Failed to load Q2_Q3_2020_Data: Dried_Fruit_Q2_(Grapes)_SUM
# Failed to load Q2_Q3_2020_Data: Fish_(Oily)_SUM
# Failed to load Q2_Q3_2020_Data: Grapes_SUM
# Failed to load Q2_Q3_2020_Data: Herbs_SUM
# Failed to load Q2_Q3_2020_Data: Infant_Formula_Q2_SUM
# Failed to load Q2_Q3_2020_Data: Kiwi_Fruit_SUM
# Failed to load Q2_Q3_2020_Data: Lamb_SUM
# Failed to load Q2_Q3_2020_Data: Lettuce_SUM
# Failed to load Q2_Q3_2020_Data: Liver_SUM
# Failed to load Q2_Q3_2020_Data: Mango_SUM
# Failed to load Q2_Q3_2020_Data: Milk_SUM
# Failed to load Q2_Q3_2020_Data: Okra_SUM
# Failed to load Q2_Q3_2020_Data: Onions_SUM
# Failed to load Q2_Q3_2020_Data: Orange_Juice_SUM
# Failed to load Q2_Q3_2020_Data: Oranges_SUM
# Failed to load Q2_Q3_2020_Data: Pears_SUM
# Failed to load Q2_Q3_2020_Data: Peas_(without_pods)_SUM
# Failed to load Q2_Q3_2020_Data: Potatoes_Q2_&_Q3_SUM
# Failed to load Q2_Q3_2020_Data: Poultry_(Meat)_SUM
# Failed to load Q2_Q3_2020_Data: Rice_Q2_SUM
# Failed to load Q2_Q3_2020_Data: Rye_SUM
# Failed to load Q2_Q3_2020_Data: Sweet_potatoes_SUM
# Importing Q3_2018_quarterly_data
# Failed to load Q3_2018_quarterly_data: Introduction
# Failed to load Q3_2018_quarterly_data: Apple_SUM
# Failed to load Q3_2018_quarterly_data: Aubergine_SUM
# Failed to load Q3_2018_quarterly_data: Banana_SUM
# Failed to load Q3_2018_quarterly_data: Beans_with_Pods_SUM
# Failed to load Q3_2018_quarterly_data: Beef_SUM
# Failed to load Q3_2018_quarterly_data: Berries_SUM
# Failed to load Q3_2018_quarterly_data: Bread_SUM
# Failed to load Q3_2018_quarterly_data: Broccoli_SUM
# Failed to load Q3_2018_quarterly_data: Cheese_(Soft)_SUM
# Failed to load Q3_2018_quarterly_data: Chinese_Cabbage_SUM
# Failed to load Q3_2018_quarterly_data: Eggs_SUM
# Failed to load Q3_2018_quarterly_data: Fish_(White)_SUM
# Failed to load Q3_2018_quarterly_data: Frozen_Fruits_SUM
# Failed to load Q3_2018_quarterly_data: Game_SUM
# Failed to load Q3_2018_quarterly_data: Ginger_SUM
# Failed to load Q3_2018_quarterly_data: Grapefruit_SUM
# Failed to load Q3_2018_quarterly_data: Grapes_SUM
# Failed to load Q3_2018_quarterly_data: Infant_Food_SUM
# Failed to load Q3_2018_quarterly_data: Lentils_SUM
# Failed to load Q3_2018_quarterly_data: Melon_SUM
# Failed to load Q3_2018_quarterly_data: Milk_SUM
# Failed to load Q3_2018_quarterly_data: Mushroom_SUM
# Failed to load Q3_2018_quarterly_data: Okra_SUM
# Failed to load Q3_2018_quarterly_data: Pears_SUM
# Failed to load Q3_2018_quarterly_data: Peppers_SUM
# Failed to load Q3_2018_quarterly_data: Pineapple_SUM
# Failed to load Q3_2018_quarterly_data: Potato_SUM
# Failed to load Q3_2018_quarterly_data: Soft_Citrus_SUM
# Failed to load Q3_2018_quarterly_data: Vine_Leaves_SUM
# Importing Q3_2019_quarterly_data
# Failed to load Q3_2019_quarterly_data: Introduction
# Failed to load Q3_2019_quarterly_data: Apple_SUM
# Failed to load Q3_2019_quarterly_data: Beans_SUM
# Failed to load Q3_2019_quarterly_data: Bread_SUM
# Failed to load Q3_2019_quarterly_data: Cabbage_SUM
# Failed to load Q3_2019_quarterly_data: Chocolate_SUM
# Failed to load Q3_2019_quarterly_data: CookedMeats_SUM
# Failed to load Q3_2019_quarterly_data: CurryLeaves_SUM
# Failed to load Q3_2019_quarterly_data: Fish_SUM
# Failed to load Q3_2019_quarterly_data: Grapes_SUM
# Failed to load Q3_2019_quarterly_data: InfantFood_SUM
# Failed to load Q3_2019_quarterly_data: Lemons_SUM
# Failed to load Q3_2019_quarterly_data: Lettuce_SUM
# Failed to load Q3_2019_quarterly_data: Milk_SUM
# Failed to load Q3_2019_quarterly_data: Okra_SUM
# Failed to load Q3_2019_quarterly_data: Pasta_SUM
# Failed to load Q3_2019_quarterly_data: Peach&Nect_SUM
# Failed to load Q3_2019_quarterly_data: Peppers_SUM
# Failed to load Q3_2019_quarterly_data: Plums_SUM
# Failed to load Q3_2019_quarterly_data: PorkMeat_SUM
# Failed to load Q3_2019_quarterly_data: Potato_SUM
# Failed to load Q3_2019_quarterly_data: Potato(proc)_SUM
# Failed to load Q3_2019_quarterly_data: Spices(turmeric)_SUM
# Failed to load Q3_2019_quarterly_data: Spinach_SUM
# Failed to load Q3_2019_quarterly_data: Strawberry_SUM
# Importing Q3_2021_quarterly_data
# Failed to load Q3_2021_quarterly_data: Summary
# Failed to load Q3_2021_quarterly_data: Aubergine_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Aubergine_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Banana_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Banana_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Beans_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Beans_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Beef_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Beef_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Berries_Small_Fruit_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Berries_Small_Fruits_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Bread_Ordinary_GB-Q3_SUM
# Failed to load Q3_2021_quarterly_data: Bread_Ordinary_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Broccoli_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Broccoli_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Cheese_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Edible_Seeds_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Eggs_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Eggs_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Fish_(White)_Q3_NI_SUM
# Failed to load Q3_2021_quarterly_data: Grapefruit_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Grapefruit_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Grapes_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Grapes_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Melon_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Melon_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Milk_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Milk_NI-Q3_SUM
# Failed to load Q3_2021_quarterly_data: Mushrooms_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Mushroom_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Olive_Oil_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Olive_Oil_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Peppers_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Peppers_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Plant_Based_Protein_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Potatoes_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Potatoes_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Raspberries_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Raspberries_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Rice_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Rice_NI_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Soya_Based_Drink_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Spring_Greens_GB_Q3_SUM
# Failed to load Q3_2021_quarterly_data: Spring_Greens_NI_Q3_SUM
# Importing Q4_2018_quarterly_data
# Failed to load Q4_2018_quarterly_data: Introduction
# Failed to load Q4_2018_quarterly_data: Animal_Fats_SUM
# Failed to load Q4_2018_quarterly_data: Apples_SUM
# Failed to load Q4_2018_quarterly_data: Aubergine_SUM
# Failed to load Q4_2018_quarterly_data: Banana_SUM
# Failed to load Q4_2018_quarterly_data: Beans_with_pods_SUM
# Failed to load Q4_2018_quarterly_data: Beef_SUM
# Failed to load Q4_2018_quarterly_data: Beer_SUM
# Failed to load Q4_2018_quarterly_data: Bread_SUM
# Failed to load Q4_2018_quarterly_data: Broccoli_SUM
# Failed to load Q4_2018_quarterly_data: Cheese_SUM
# Failed to load Q4_2018_quarterly_data: Eggs_SUM
# Failed to load Q4_2018_quarterly_data: Fish_SUM
# Failed to load Q4_2018_quarterly_data: Frozen_Fruits_SUM
# Failed to load Q4_2018_quarterly_data: Game_SUM
# Failed to load Q4_2018_quarterly_data: Ginger_SUM
# Failed to load Q4_2018_quarterly_data: Grapefruit_SUM
# Failed to load Q4_2018_quarterly_data: Grapes_SUM
# Failed to load Q4_2018_quarterly_data: Lettuce_SUM
# Failed to load Q4_2018_quarterly_data: Melon_SUM
# Failed to load Q4_2018_quarterly_data: Milk_SUM
# Failed to load Q4_2018_quarterly_data: Mushroom_SUM
# Failed to load Q4_2018_quarterly_data: Okra_SUM
# Failed to load Q4_2018_quarterly_data: Olive_oil_SUM
# Failed to load Q4_2018_quarterly_data: Pears_SUM
# Failed to load Q4_2018_quarterly_data: Peas_without_pods_SUM
# Failed to load Q4_2018_quarterly_data: Peppers_SUM
# Failed to load Q4_2018_quarterly_data: Pineapple_SUM
# Failed to load Q4_2018_quarterly_data: Potatoes_SUM
# Failed to load Q4_2018_quarterly_data: Soft_Citrus_SUM
# Failed to load Q4_2018_quarterly_data: Speciality_Vegetables_SUM
# Failed to load Q4_2018_quarterly_data: Wheat_SUM
# Importing Q4_2019_quarterly_data
# Failed to load Q4_2019_quarterly_data: Introduction
# Failed to load Q4_2019_quarterly_data: Apple_SUM
# Failed to load Q4_2019_quarterly_data: Barley_SUM
# Failed to load Q4_2019_quarterly_data: Beans_SUM
# Failed to load Q4_2019_quarterly_data: Bread(gluten_free)_SUM
# Failed to load Q4_2019_quarterly_data: Bread_SUM
# Failed to load Q4_2019_quarterly_data: Butter_SUM
# Failed to load Q4_2019_quarterly_data: Cheese_SUM
# Failed to load Q4_2019_quarterly_data: Chillies_SUM
# Failed to load Q4_2019_quarterly_data: Fish(sea)_SUM
# Failed to load Q4_2019_quarterly_data: Grapes_SUM
# Failed to load Q4_2019_quarterly_data: Honey_SUM
# Failed to load Q4_2019_quarterly_data: Lemon_SUM
# Failed to load Q4_2019_quarterly_data: Lettuce_SUM
# Failed to load Q4_2019_quarterly_data: Milk_SUM
# Failed to load Q4_2019_quarterly_data: Oats_SUM
# Failed to load Q4_2019_quarterly_data: Okra_SUM
# Failed to load Q4_2019_quarterly_data: Peach&Nect_SUM
# Failed to load Q4_2019_quarterly_data: Pepper_SUM
# Failed to load Q4_2019_quarterly_data: Plums_SUM
# Failed to load Q4_2019_quarterly_data: Pork_SUM
# Failed to load Q4_2019_quarterly_data: Potato(proc)_SUM
# Failed to load Q4_2019_quarterly_data: Potatoes_SUM
# Failed to load Q4_2019_quarterly_data: PrePack_Salad_SUM
# Failed to load Q4_2019_quarterly_data: Rice_SUM
# Failed to load Q4_2019_quarterly_data: Shellfish_SUM
# Failed to load Q4_2019_quarterly_data: Spinach_SUM
# Failed to load Q4_2019_quarterly_data: Strawberry_SUM
# Failed to load Q4_2019_quarterly_data: Tomato_SUM
# Importing Q4_2020_Data
# Failed to load Q4_2020_Data: Introduction
# Failed to load Q4_2020_Data: Beans_with_Pods_Q4_(SUM)
# Failed to load Q4_2020_Data: Bread_Q4_(SUM)
# Failed to load Q4_2020_Data: Carrots_Q4_(SUM)
# Failed to load Q4_2020_Data: Cauliflower_Q4_(SUM)
# Failed to load Q4_2020_Data: Cheese_(Hard)_Q4_(SUM)
# Failed to load Q4_2020_Data: Courgette_Q4_(SUM)
# Failed to load Q4_2020_Data: Dried_Fruits_(Grapes)_Q4_(SUM)
# Failed to load Q4_2020_Data: Fish_(Oily)_Q4_(SUM)
# Failed to load Q4_2020_Data: Grapes_Q4_(SUM)
# Failed to load Q4_2020_Data: Kiwi_Fruit_Q4_(SUM)
# Failed to load Q4_2020_Data: Lamb_Q4_(SUM)
# Failed to load Q4_2020_Data: Liver_(Bovine)_Q4_(SUM)
# Failed to load Q4_2020_Data: Mango_Q4_(SUM)
# Failed to load Q4_2020_Data: Milk_Q4_(SUM)
# Failed to load Q4_2020_Data: Okra_Q4_(SUM)
# Failed to load Q4_2020_Data: Onions_Q4_(SUM)
# Failed to load Q4_2020_Data: Oranges_Q4_(SUM)
# Failed to load Q4_2020_Data: Pate_(Fish)_Q4_(SUM)
# Failed to load Q4_2020_Data: Pears_Q4_(SUM)
# Failed to load Q4_2020_Data: Peas_with_Pods_Q4_(SUM)
# Failed to load Q4_2020_Data: Potatoes_Q4_(SUM)
# Failed to load Q4_2020_Data: Poultry_Meat_Q4_(SUM)
# Failed to load Q4_2020_Data: Pumpkin_&_Squash_Q4_(SUM)
# Failed to load Q4_2020_Data: Rye_Q4_(SUM)
# Failed to load Q4_2020_Data: Sweet_Potatoes_Q4_(SUM)
# Importing Q4_2021_PRIF_Quarterly_Report
# Failed to load Q4_2021_PRIF_Quarterly_Report: Summary
# Failed to load Q4_2021_PRIF_Quarterly_Report: Asparagus_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Asparagus_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Aubergine_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Aubergine_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Banana_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Banana_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Beans_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Beans_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Beef_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Beef_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Berries_Small_Fruit_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Berries_Small_Fruits_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Bread_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Bread_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Broccoli_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Broccoli_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Cheese_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Cheese_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Eggs_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Eggs_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Fish_(White)_Q4_NI_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Grapefruit_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Grapefruit_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Grapes_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Grapes_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Infant_Food_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Infant_Food_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Melon_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Melon_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Milk_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Milk_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Mushrooms_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Mushrooms_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Nuts_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Olive_Oil_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Olive_Oil_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Pepper_Processed_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Peppers_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Peppers_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Potatoes_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Potatoes_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Raspberries_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Raspberries_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Spring_Greens_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Spring_Greens_NI_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Wheat_GB_Q4_SUM
# Failed to load Q4_2021_PRIF_Quarterly_Report: Wheat_NI_Q4_SUM
# Importing September_2022_rolling_reports
# Failed to load September_2022_rolling_reports: Summary

# %%
all_dfs
# Out:
#           Sample ID     Date of Sampling                Description  \
# 0   Cooking                         None                       None
# 1         1958/2016  2016-08-08T00:00:00             Bramley Apples
# 2         1958/2016  2016-08-08T00:00:00             Bramley Apples
# 3         0230/2016  2016-08-08T00:00:00             Bramley Apples
# 4         0230/2016  2016-08-08T00:00:00             Bramley Apples
# ..              ...                  ...                        ...
# 40        0792/2022  2022-09-08T00:00:00  Marfona Unwashed Potatoes
# 41        0765/2022  2022-09-14T00:00:00           Sagitta Potatoes
# 42        0938/2022  2022-09-01T00:00:00      Marfona Ware Potatoes
# 43        0833/2022  2022-08-31T00:00:00               Lady Rosetta
# 44        0833/2022  2022-08-31T00:00:00               Lady Rosetta
#
#    Country of Origin Retail Outlet  \
# 0               None          None
# 1                 UK          Asda
# 2                 UK          Asda
# 3                 UK         Co-op
# 4                 UK         Co-op
# ..               ...           ...
# 40                UK           NaN
# 41                UK           NaN
# 42                UK           NaN
# 43      England (UK)           NaN
# 44      England (UK)           NaN
#
#                                               Address    Brand Name  \
# 0                                                None          None
# 1                  Creechbarrow Road, Taunton TA1 2AN         Asda
# 2                  Creechbarrow Road, Taunton TA1 2AN         Asda
# 3                           Northgate, Louth LN11 0LT        Co-op
# 4                           Northgate, Louth LN11 0LT        Co-op
# ..                                                ...           ...
# 40  77 Havant Road, Hayling Island, Hampshire PO11...  None stated
# 41  Callywith Gate Industrial Estate, Launceston R...  None stated
# 42                   Fengate, Moulton Chapel PE12 0XL  None stated
# 43  Tyrrells Court, Stretford Bridge, Leominster H...  None stated
# 44  Tyrrells Court, Stretford Bridge, Leominster H...  None stated
#
#                         Packer / Manufacturer  \
# 0                                        None
# 1          Asda Stores Ltd Leeds, UK LS11 5AD
# 2          Asda Stores Ltd Leeds, UK LS11 5AD
# 3   Co-operative Group Ltd Manchester M60 0AG
# 4   Co-operative Group Ltd Manchester M60 0AG
# ..                                        ...
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
#
#    Pesticide residues found in mg/kg (MRL)        product  \
# 0                                     None      Apple_BNA
# 1                  boscalid 0.03 (MRL = 2)      Apple_BNA
# 2          pyraclostrobin 0.01 (MRL = 0.5)      Apple_BNA
# 3                  boscalid 0.05 (MRL = 2)      Apple_BNA
# 4        flonicamid (sum) 0.02 (MRL = 0.2)      Apple_BNA
# ..                                     ...            ...
# 40         maleic hydrazide 7.7 (MRL = 60)  Potatoes_(GB)
# 41          maleic hydrazide 17 (MRL = 60)  Potatoes_(GB)
# 42     None were detected above the set RL  Potatoes_(GB)
# 43     None were detected above the set RL  Potatoes_(GB)
# 44     None were detected above the set RL  Potatoes_(GB)
#
#             Sampling Point                   Packer / Manufacturer / Importer
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ..                     ...                                                ...
# 40        Stoke Fruit Farm  Stoke Fruit Farm 77 Havant Road, Hayling Islan...
# 41      Total Produce Ltd.       CS Duston & Son Colwith Farm, Par, Cornwall
# 42  Tulipland Potatoes Ltd                                 Garden of Elveden
# 43         Tyrrells Crisps                                         KP Crisps
# 44         Tyrrells Crisps                                         KP Crisps
#
# [41997 rows x 12 columns]

# %% [markdown]
# ## Overview
#
# Types of analysis:#
#
# 1. Summary of each product (apples or aubergines),
#     - grouped by country of origin#
#     - under each Country group, results grouped by detected chemicals (DC)#
#     - for each DC, show the count of products with some detected and the range they were in#
#     - for each DC, show the count of products with none-detected#
# 2. Counts of product items grouped by country of origin,
#     - e.g "Apples from USA = 6, Apples from France = 3 "#
# 3. Distribution of DCs grouped by country of origin,
#     - e.g. boscalid : UK = 2, USA = 5.#
# 4. Statement of Count Range of DCs found in how many of total number of samples,
#     - e.g. "Residues (ranging from 1 to 11) were detected in 12 of 24 of the samples analysed"#
# 5. A table showing number of residues, sample ID, Type of apple, amounts of each DC (and a '-' if n/a) and the country of origin#
# 6. total list of chemicals analysed for but not found.
#
# # ideas:#
# 1. for each product, show pie chart of prods with none detected, one detected, multiple detected#
# 2. same as above,
#     - but filter by supermarket.#
#     - 2b) same as above but filter by country of origin#
#     - 2c) same as above but show breakdown#
# 3. scattergraph of amounts detected across product category, compared to MRLs (either individual DCs or agregated)#
# 4. Stacked bargraph showing total amount detected per sample, with a different colour to represent each DC.#
# 5. some kind of graph to represent the chemicals that were not detected!
#
#
#
# ## Things to include ths
#
# - date as date time or seperated to year, month, day
# - check works with other files from url
# - use bs from different pc?
#     - sort bs code out
# - build basic as streamlit
# - unittests
# - postcode to map

# %%
# dfAll=[]
# for file in file_path:
#     print(file.split('\\')[-1])
#     df = import_ods(file)
#     print(df.columns)
#     dfAll.append(df)

# %%
# 
# df2

# dfAll[1]
ii=0
print(file_path[ii])
df = import_ods(file_path[ii])

df2 = modify_df(df)

df2

# %%
# df2.loc[df2['product']=="Wine"]
pd.DatetimeIndex(df2['date_of_sampling']).year
pd.DatetimeIndex(df2['date_of_sampling']).month

df2['date_of_sampling'].dt.day


def plot_time(group_how='count'):
    if group_how=='count':
        df3 = df2.groupby(pd.DatetimeIndex(df2['date_of_sampling']).month).count()
        plt.plot(df3.index, df3['amount_detected'],'ok-')
    else:
        df3 = df2.groupby(pd.DatetimeIndex(df2['date_of_sampling']).month).mean()
        plt.plot(df3.index, df3[group_how],'ok-')
    # print(df3)
plot_time('mrl')

# %%
max(pd.DatetimeIndex(df2['date_of_sampling']).month)

# %% [markdown]
# 1. Summary of each product (apples or aubergines),
#     - grouped by country of origin#
#     - under each Country group, results grouped by detected chemicals (DC)#
#     - for each DC, show the count of products with some detected and the range they were in#
#     - for each DC, show the count of products with none-detected#
# 2. Counts of product items grouped by country of origin,
#     - e.g "Apples from USA = 6, Apples from France = 3 "#
# 3. Distribution of DCs grouped by country of origin,
#     - e.g. boscalid : UK = 2, USA = 5.#
# 4. Statement of Count Range of DCs found in how many of total number of samples,
#     - e.g. "Residues (ranging from 1 to 11) were detected in 12 of 24 of the samples analysed"#
# 5. A table showing number of residues, sample ID, Type of apple, amounts of each DC (and a '-' if n/a) and the country of origin#
# 6. total list of chemicals analysed for but not found.

# %%
product = 'Wine'
date_low = '2016-06-01'
date_high = '2017-06-01'
data_sql = sqldf(f"""
SELECT 
    chem_name,	SUM(amount_detected) AS sum_detected, 
    country_of_origin, COUNT(*) as count_tests
FROM 
    df2
WHERE 
    product =  '{product}' AND
    date_of_sampling > '{date_low}' AND
    date_of_sampling < '{date_high}' 
    
GROUP BY
    country_of_origin, chem_name
""", locals()
)

data_sql

# %%
"""
SELECT 
    chem_name,	SUM(amount_detected) AS sum_detected, 
    country_of_origin, COUNT(*) as count_tests
FROM 
    df2
WHERE 
    product =  '{}' AND
    date_of_sampling > '2016-06-01' 
GROUP BY
    country_of_origin, chem_name
""".format(product)

# %%
data = data_sql#.loc[:,'sum_detected']
data.groupby('chem_name',as_index=False).sum()
# data

# %%
def plot_pie_by_chem(data_sql, country='USA', what_to_plot='sum_detected'):

    if country =='all':
        data_sql = data_sql.groupby('chem_name',as_index=False).sum()
        data = data_sql.loc[:,what_to_plot]
        labels = data_sql.loc[:,'chem_name']
    
    else:
        data = data_sql.loc[data_sql['country_of_origin']==country,what_to_plot]
        labels = data_sql.loc[data_sql['country_of_origin']==country,'chem_name']
    #define Seaborn color palette to use
    colors = sns.color_palette('pastel')[0:len(labels)]

    plt.pie(data, labels=labels, colors = colors,
        autopct='%.0f%%', normalize=True);
    plt.title(what_to_plot + ' from country = ' + country  )




def plot_pie_by_chem2(data_sql, chemical_country='boscalid', what_to_plot='sum_detected',is_country=True):

    if is_country:
        label_plot ='country_of_origin'
        title_str = what_to_plot + ' by chemical = ' + chemical_country
        selective = 'chem_name'
    else:
        label_plot = 'chem_name'
        title_str = what_to_plot + ' from country = ' + chemical_country
        selective = 'country_of_origin'

    if chemical_country =='all':
        data_sql = data_sql.groupby(label_plot,as_index=False).sum()
        data = data_sql.loc[:,what_to_plot]
        labels = data_sql.loc[:,label_plot]
    
    else:
        data = data_sql.loc[data_sql[selective]==chemical_country,what_to_plot]
        labels = data_sql.loc[data_sql[selective]==chemical_country,label_plot]
    
    #define Seaborn color palette to use
    colors = sns.color_palette('pastel')[0:len(labels)]

    plt.pie(data, labels=labels, colors = colors,
        autopct='%.0f%%', normalize=True);
    plt.title( title_str  )

# plot_pie_by_chem(data_sql,'USA','sum_detected'),
plot_pie_by_chem2(data_sql,'all','sum_detected',False)
# data_sql

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = data_sql.loc[data_sql['chem_name']=='boscalid','sum_detected']
labels = data_sql.loc[data_sql['chem_name']=='boscalid','country_of_origin']
#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:len(labels)]

plt.pie(data, labels=labels, colors = colors,
    autopct='%.0f%%', normalize=True);
