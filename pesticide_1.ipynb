# %%
import pandas as pd
import ezodf
from modify_dfs import *
import os

# %%
s_fname = "C:\\Users\simmt\Code1\Pesticide\data\August_2022_rolling_reports.ods"
# doc = ezodf.opendoc(s_fname)

# %%
folder_path = 'C:\\Users\simmt\Code1\Pesticide\Pesticide-main\data_files'
file_path = []
for x in os.listdir(folder_path):
    file_path.append(os.path.join(folder_path,x) )

    
doc = ezodf.opendoc(file_path[0])
# get last sheet
sheet = doc.sheets[-4]

# %%
df_dict = {}
print(sheet.name)
for i, row in enumerate(sheet.rows()):
#     row is a list of cells
# #     assume the header is on the first row
    if i == 2:
    # columns as lists in a dictionary
        df_dict = {cell.value:[] for cell in row}
df_dict
# Out:
# TinTomatoes_BNA
# {'1606/2016': [],
#  '2016-04-15T00:00:00': [],
#  'Sweet Harvest Peeled Plum Tomatoes': [],
#  'Italy': [],
#  'Aldi': [],
#  'Newbridge Hill, Louth LN11 0NQ': [],
#  'Aldi ': [],
#  'Aldi Stores Ltd PO Box 26, Atherstone, Warwickshire CV9 2SH': [],
#  'None were detected above the set RL': [],
#  None: []}

# %%
data_sheet = []
for i,row in enumerate(sheet.rows()):
    if i==0:
        column_names = [cell.value for cell in row]
        print(column_names)
    else:
        data_sheet.append( [cell.value for cell in row] )
ddf = pd.DataFrame(data_sheet)

ddf.columns = column_names

ddf
# Out:
# ['Sample ID', 'Date of Sampling', 'Description', 'Country of Origin', 'Retail Outlet', 'Address', 'Brand Name', 'Packer / Manufacturer', 'Pesticide residues found in mg/kg (MRL)', None]
#             Sample ID     Date of Sampling  \
# 0           1605/2016  2016-04-15T00:00:00
# 1           1606/2016  2016-04-15T00:00:00
# 2           1752/2016  2016-05-05T00:00:00
# 3           1753/2016  2016-05-05T00:00:00
# 4           0400/2016  2016-05-10T00:00:00
# 5           1740/2016  2016-05-06T00:00:00
# 6   1622/2016 Organic  2016-04-16T00:00:00
# 7           1638/2016  2016-04-16T00:00:00
# 8           1607/2016  2016-04-15T00:00:00
# 9           1608/2016  2016-04-15T00:00:00
# 10          1609/2016  2016-04-15T00:00:00
# 11          1610/2016  2016-04-15T00:00:00
# 12          1611/2016  2016-04-15T00:00:00
# 13          1612/2016  2016-04-15T00:00:00
# 14          1613/2016  2016-04-15T00:00:00
# 15          1614/2016  2016-04-15T00:00:00
# 16  1741/2016 Organic  2016-05-05T00:00:00
# 17          1742/2016  2016-05-05T00:00:00
# 18  1743/2016 Organic  2016-05-05T00:00:00
# 19          1744/2016  2016-05-05T00:00:00
# 20          1745/2016  2016-05-05T00:00:00
# 21          1747/2016  2016-05-05T00:00:00
# 22          1748/2016  2016-05-05T00:00:00
# 23          1751/2016  2016-05-05T00:00:00
# 24               None                 None
#
#                                 Description Country of Origin Retail Outlet  \
# 0     Sweet Harvest Chunky Chopped Tomatoes             Italy          Aldi
# 1        Sweet Harvest Peeled Plum Tomatoes             Italy          Aldi
# 2                   Chunky Chopped Tomatoes             Italy          Aldi
# 3                      Peeled Plum Tomatoes             Italy          Aldi
# 7           Co-operative Group Ltd Manchester M60 0AG
# 8         Wm Morrison PLC Gain Lane, Bradford BD3 7DL
# 9         Wm Morrison PLC Gain Lane, Bradford BD3 7DL
# 10  Dawood Exports Ltd 5, Buroh Lane, 09-01, Singa...
# 11  LDH La Doria Ltd Huntingdon, Cambridgeshire PE...
# 12  Napolina Ltd Royal Liver Building, Pier Head, ...
# 13  Napolina Ltd Royal Liver Building, Pier Head, ...
# 14  LDH La Doria Ltd Parsons Green, St Ives, Cambr...
# 15  Conserve Italia Soc Co-op Agricola Via P Poggi...
# 16        Sainsburys Supermarkets Ltd London EC1N 2HT
# 17  Napolina Ltd Royal Liver Building, Pier Head, ...
# 18        Sainsburys Supermarkets Ltd London EC1N 2HT
# 19  Napolina Ltd Royal Liver Building, Pier Head, ...
# 20        Sainsburys Supermarkets Ltd London EC1N 2HT
# 21  Conserve Italia Soc Co-op Agricola Via P Poggi...
# 22  LDH La Doria Ltd Parsons Green, St Ives, Cambr...
# 23                  Tesco Stores Ltd Cheshunt EN8 9SL
# 24                                               None
#
#    Pesticide residues found in mg/kg (MRL)  None
# 0      None were detected above the set RL  None
# 1      None were detected above the set RL  None
# 2      None were detected above the set RL  None
# 3      None were detected above the set RL  None
# 4      None were detected above the set RL  None
# 5      None were detected above the set RL  None
# 6      None were detected above the set RL  None
# 7      None were detected above the set RL  None
# 8      None were detected above the set RL  None
# 9      None were detected above the set RL  None
# 10     None were detected above the set RL  None
# 11     None were detected above the set RL  None
# 12       flonicamid (sum) 0.01 (MRL = 0.3)  None
# 13     None were detected above the set RL  None
# 14     None were detected above the set RL  None
# 15     None were detected above the set RL  None
# 16     None were detected above the set RL  None
# 17     None were detected above the set RL  None
# 18     None were detected above the set RL  None
# 19     None were detected above the set RL  None
# 20     None were detected above the set RL  None
# 21     None were detected above the set RL  None
# 22     None were detected above the set RL  None
# 23     None were detected above the set RL  None
# 24                                    None  None

# %%
def import_ods(fname):
    doc = ezodf.opendoc(s_fname)
    for i, sheet in enumerate(doc.sheets):
        if i!=0: #ignore 1st sheet
            product = sheet.name
            print(product)
            
            df_new =import_ods_inner(sheet)
            df_new.columns = df_new.columns.str.strip()
            try:
                df = pd.concat([df,df_new])
            except:
                df = df_new
                
    return df
            
def import_ods_inner(sheet):
    df_dict = {}
    for i, row in enumerate(sheet.rows()):
    #     row is a list of cells
# #     assume the header is on the first row
        if i == 1:
        # columns as lists in a dictionary
            df_dict = {cell.value:[] for cell in row}

    # create index for the column headers
    for i,row in enumerate(sheet.rows()):
        if i == 0:
            continue
        elif i == 1:
            col_index = [cell.value for cell in row]
            continue
        for j,cell in enumerate(row):
            df_dict[col_index[j]].append(cell.value)
            
    # delete none column
    try:
        del df_dict[None]
    except:
        pass
    # and convert to a DataFrame
    df = pd.DataFrame(df_dict)
    
    # fill based on previous values    
    df.fillna(method='ffill', inplace=True)

    return df

# %%
df = import_ods(s_fname)

modify_df(df)
# import re
# def extract_pcode(x):  
#     regexp = r'([A-Za-z]+[0-9]+\s[0-9]+[A-Za-z]+$)'
#     try:
#         return re.findall(regexp,x)[0]
#     except:
#         return 0
# eg_pc = 'hdwhck ss1 2wg'
# regexp = r'([A-Za-z]+[0-9]+\s[0-9]+[A-Za-z]+$)'
                      
                      
# # df = extract_pcode(df,'Address')
# df['Address'].apply(extract_pcode)
# Out:
# Beans_with_Pods_(GB)
# Grapes_(GB)
# Potatoes_(GB)
#             sample_id     date_of_sampling  \
# 0           3729/2022  2022-08-08T00:00:00
# 1           3729/2022  2022-08-08T00:00:00
# 2           5951/2022  2022-08-08T00:00:00
# 3           1941/2022  2022-08-08T00:00:00
# 4           1975/2022  2022-08-08T00:00:00
# 5           1901/2022  2022-08-08T00:00:00
# 6           1946/2022  2022-08-08T00:00:00
# 7           1946/2022  2022-08-08T00:00:00
# 8           2003/2022  2022-08-08T00:00:00
# 9           2003/2022  2022-08-08T00:00:00
# 10          6126/2022  2022-08-09T00:00:00
# 11          1253/2022  2022-08-10T00:00:00
# 12          1253/2022  2022-08-10T00:00:00
# 13          1253/2022  2022-08-10T00:00:00
# 14          1253/2022  2022-08-10T00:00:00
# 15          1258/2022  2022-08-10T00:00:00
# 16          1258/2022  2022-08-10T00:00:00
# 17          1951/2022  2022-08-08T00:00:00
# 18          1951/2022  2022-08-08T00:00:00
# 19          1951/2022  2022-08-08T00:00:00
# 20          6155/2022  2022-08-22T00:00:00
# 21          6155/2022  2022-08-22T00:00:00
# 22          6155/2022  2022-08-22T00:00:00
# 23  1227/2022 Organic  2022-08-23T00:00:00
# 24          3731/2022  2022-08-08T00:00:00
# 25          3731/2022  2022-08-08T00:00:00
# 26          3731/2022  2022-08-08T00:00:00
# 27          0656/2022  2022-08-08T00:00:00
# 28          0656/2022  2022-08-08T00:00:00
# 29          0656/2022  2022-08-08T00:00:00
# 30          0656/2022  2022-08-08T00:00:00
# 31          0656/2022  2022-08-08T00:00:00
# 32          1903/2022  2022-08-08T00:00:00
# 33          1903/2022  2022-08-08T00:00:00
# 34          1262/2022  2022-08-16T00:00:00
# 35          1262/2022  2022-08-16T00:00:00
# 36          1262/2022  2022-08-16T00:00:00
# 37          1947/2022  2022-08-08T00:00:00
# 38          1947/2022  2022-08-08T00:00:00
# 39          1947/2022  2022-08-08T00:00:00
# 40          1281/2022  2022-07-27T00:00:00
# 41          1282/2022  2022-07-27T00:00:00
# 42          1072/2022  2022-08-02T00:00:00
# 43          0810/2022  2022-07-27T00:00:00
# 44  0813/2022 Organic  2022-07-27T00:00:00
# 45          0814/2022  2022-07-27T00:00:00
# 46          0815/2022  2022-07-27T00:00:00
# 47          0876/2022  2022-08-25T00:00:00
# 48          0873/2022  2022-07-26T00:00:00
# 49          0919/2022  2022-07-26T00:00:00
# 50          0919/2022  2022-07-26T00:00:00
#
#                               description country_of_origin  \
# 0                        Extra Fine Beans         Guatemala
# 1                        Extra Fine Beans         Guatemala
# 2                  Extra Fine Green Beans             Kenya
# 3                             Green Beans                UK
# 4                             Green Beans                UK
# 40  Mercian Ltd Unit 3 & 4, The Barns, Highfield F...
# 41  Mercian Ltd Unit 3 & 4, The Barns, Highfield F...
# 42   PJ Lee and Sons Ltd High Flyer Farm, Ely CB7 4RA
# 43  Yapro Ltd Hanegev Building, Reem Junction DN S...
# 44  Alumim Atzmona Potatoes Ltd Mivtachim DN Negev...
# 45  Yapro Ltd Hanegev Building, Reem Junction DN S...
# 46         Atzmona Mivtachim DN Negev, 85440, Israel
# 47  JT Hopkins & Sons Carsaig Farm, High Street, W...
# 48  Mercian Ltd Unit 3 & 4, The Barns, Highfield F...
# 49  R.S. Cockerill (York) Ltd Providence Business ...
# 50  R.S. Cockerill (York) Ltd Providence Business ...
#
#    pesticide_residues_found_in_mg/kg_(mrl) address_postcode packer__postcode  \
# 0              tebuconazole 0.03 (MRL = 2)         BN41 1GB          AL7 1GA
# 1                 fluopyram 0.06 (MRL = 1)         BN41 1GB          AL7 1GA
# 2        cyantraniliprole 0.02 (MRL = 1.5)         AB11 5EJ          CV9 2SH
# 3                                      n/a         YO32 9LF         LS11 5AD
# 4         flonicamid (sum) 0.1 (MRL = 1.5)          E18 1AY         CH99 9QS
# 5              azoxystrobin 0.02 (MRL = 3)         ME15 9NN          BD3 7DL
# 6                                      n/a          B75 5BT                0
# 7                                      n/a          B75 5BT                0
# 8       spirotetramat (sum) 0.05 (MRL = 2)         AB11 5EJ          CV9 2SH
# 9            trifloxystrobin 0.1 (MRL = 3)         AB11 5EJ          CV9 2SH
# 10             azoxystrobin 0.02 (MRL = 3)          DL3 0UW                0
# 11          metalaxyl (sum) 0.02 (MRL = 2)         DA17 6JY          ME9 7TT
# 12                 boscalid 0.03 (MRL = 5)         DA17 6JY          ME9 7TT
# 13                  ethephon 0.8 (MRL = 1)         DA17 6JY          ME9 7TT
# 14               fluopyram 0.2 (MRL = 1.5)         DA17 6JY          ME9 7TT
# 15            spiroxamine 0.03 (MRL = 0.6)         DA17 6JY          ME9 7TT
# 16            acetamiprid 0.01 (MRL = 0.5)         DA17 6JY          ME9 7TT
# 17               cyprodinil 0.03 (MRL = 3)         YO32 9LF         LS11 5AD
# 18             azoxystrobin 0.03 (MRL = 3)         YO32 9LF         LS11 5AD
# 19                 ethephon 0.08 (MRL = 1)         YO32 9LF         LS11 5AD
# 20      spirotetramat (sum) 0.01 (MRL = 2)           B6 7EU                0
# 21       chlorantraniliprole 0.1 (MRL = 1)           B6 7EU                0
# 22              etofenprox 0.02 (MRL = 4*)           B6 7EU                0
# 23                                     n/a         TW13 7DU                0
# 24                  boscalid 0.4 (MRL = 5)          BN3 7PN          KT5 9NU
# 25      spirotetramat (sum) 0.05 (MRL = 2)          BN3 7PN          KT5 9NU
# 26          trifloxystrobin 0.07 (MRL = 3)          BN3 7PN          KT5 9NU
# 27           deltamethrin 0.03 (MRL = 0.2)          TA6 4AT          BD4 9LR
# 28               cyprodinil 0.02 (MRL = 3)          TA6 4AT          BD4 9LR
# 29      spirotetramat (sum) 0.07 (MRL = 2)          TA6 4AT          BD4 9LR
# 30              fluopyram 0.04 (MRL = 1.5)          TA6 4AT          BD4 9LR
# 31                  ethephon 0.4 (MRL = 1)          TA6 4AT          BD4 9LR
# 32          metalaxyl (sum) 0.02 (MRL = 2)         ME15 9NN          BD3 7DL
# 33              fluopyram 0.02 (MRL = 1.5)         ME15 9NN          BD3 7DL
# 34          trifloxystrobin 0.01 (MRL = 3)          EN8 7RQ                0
# 35                 ethephon 0.08 (MRL = 1)          EN8 7RQ                0
# 36              fenhexamid 0.08 (MRL = 15)          EN8 7RQ                0
# 37             spiroxamine 0.2 (MRL = 0.6)          B75 5BT                0
# 38               metrafenone 0.2 (MRL = 7)          B75 5BT                0
# 39               metrafenone 0.2 (MRL = 7)          B75 5BT                0
# 40                                     n/a         NW10 7ST                0
# 41                                     n/a         NW10 7ST                0
# 42          maleic hydrazide 18 (MRL = 60)         PE15 0YG          CB7 4RA
# 43                                     n/a         SS17 9DY                0
# 44                                     n/a         SS17 9DY                0
# 45                                     n/a         SS17 9DY                0
# 46                                     n/a         SS17 9DY                0
# 47                                     n/a          BL8 1FZ          ON9 2BT
# 48                                     n/a          WN8 9QF         SK11 9BN
# 49                                     n/a          WN8 9QF         YO19 5AE
# 50                                     n/a          WN8 9QF         YO19 5AE
#
#               chem_name amount_detected  mrl
# 0          tebuconazole            0.03    2
# 1             fluopyram            0.06    1
# 2      cyantraniliprole            0.02  1.5
# 3                     0               0    0
# 4      flonicamid (sum)             0.1  1.5
# 5          azoxystrobin            0.02    3
# 6                     0               0    0
# 7                     0               0    0
# 8   spirotetramat (sum)            0.05    2
# 9       trifloxystrobin             0.1    3
# 10         azoxystrobin            0.02    3
# 11      metalaxyl (sum)            0.02    2
# 12             boscalid            0.03    5
# 13             ethephon             0.8    1
# 14            fluopyram             0.2  1.5
# 15          spiroxamine            0.03  0.6
# 16          acetamiprid            0.01  0.5
# 17           cyprodinil            0.03    3
# 18         azoxystrobin            0.03    3
# 19             ethephon            0.08    1
# 20  spirotetramat (sum)            0.01    2
# 21  chlorantraniliprole             0.1    1
# 22                    0               0    0
# 23                    0               0    0
# 24             boscalid             0.4    5
# 25  spirotetramat (sum)            0.05    2
# 26      trifloxystrobin            0.07    3
# 27         deltamethrin            0.03  0.2
# 28           cyprodinil            0.02    3
# 29  spirotetramat (sum)            0.07    2
# 30            fluopyram            0.04  1.5
# 31             ethephon             0.4    1
# 32      metalaxyl (sum)            0.02    2
# 33            fluopyram            0.02  1.5
# 34      trifloxystrobin            0.01    3
# 35             ethephon            0.08    1
# 36           fenhexamid            0.08   15
# 37          spiroxamine             0.2  0.6
# 38          metrafenone             0.2    7
# 39          metrafenone             0.2    7
# 40                    0               0    0
# 41                    0               0    0
# 42     maleic hydrazide              18   60
# 43                    0               0    0
# 44                    0               0    0
# 45                    0               0    0
# 46                    0               0    0
# 47                    0               0    0
# 48                    0               0    0
# 49                    0               0    0
# 50                    0               0    0

# %%
# convert the first sheet to a pandas.DataFrame
sheet = doc.sheets[2]
product = sheet.name
df_dict = {}
for i, row in enumerate(sheet.rows()):
#     row is a list of cells
# #     assume the header is on the first row
    if i == 1:
        # columns as lists in a dictionary
#         print(cell.value)
#         df_dict.update({cell.value:[]})
        df_dict = {cell.value:[] for cell in row}
# df_dict

#         # create index for the column headers
for i,row in enumerate(sheet.rows()):
    if i == 0:
        continue
    elif i == 1:
        col_index = [cell.value for cell in row]
#         print([cell.value for cell in row])
        continue
    for j,cell in enumerate(row):
#         print (j,cell.value)
        df_dict[col_index[j]].append(cell.value)
# # # and convert to a DataFrame
try:
    del df_dict[None]
except:
    pass

df = pd.DataFrame(df_dict)


df.head()
# Out:
#    Sample ID     Date of Sampling         Description Country of Origin  \
# 0  2493/2022  2022-09-05T00:00:00  Ivory White Grapes             Spain
# 1  2493/2022  2022-09-05T00:00:00  Ivory White Grapes             Spain
# 2  2493/2022  2022-09-05T00:00:00  Ivory White Grapes             Spain
# 3  2493/2022  2022-09-05T00:00:00  Ivory White Grapes             Spain
# 4  2493/2022  2022-09-05T00:00:00  Ivory White Grapes             Spain
#
#   Sampling Point                                            Address  \
# 0           Aldi  Cameron Toll Shopping Centre, 6 Lady Road, Edi...
# 1           Aldi  Cameron Toll Shopping Centre, 6 Lady Road, Edi...
# 2           Aldi  Cameron Toll Shopping Centre, 6 Lady Road, Edi...
# 3           Aldi  Cameron Toll Shopping Centre, 6 Lady Road, Edi...
# 4           Aldi  Cameron Toll Shopping Centre, 6 Lady Road, Edi...
#
#              Brand Name                   Packer / Manufacturer / Importer  \
# 0  Everyday Essentials   Aldi Stores Ltd PO Box 26. Atherstone, Warwick...
# 1  Everyday Essentials   Aldi Stores Ltd PO Box 26. Atherstone, Warwick...
# 2  Everyday Essentials   Aldi Stores Ltd PO Box 26. Atherstone, Warwick...
# 3  Everyday Essentials   Aldi Stores Ltd PO Box 26. Atherstone, Warwick...
# 4  Everyday Essentials   Aldi Stores Ltd PO Box 26. Atherstone, Warwick...
#
#   Pesticide residues found in mg/kg (MRL)
# 0           deltamethrin 0.02 (MRL = 0.2)
# 1               cyazofamid 0.02 (MRL = 2)
# 2          trifloxystrobin 0.03 (MRL = 3)
# 3      spirotetramat (sum) 0.02 (MRL = 2)
# 4               fluopyram 0.6 (MRL = 1.5)

# %%
[ (x, len(df_dict[x])) for x in df_dict]
#
# Out:
# [('Sample ID', 34),
#  ('Date of Sampling', 34),
#  ('Description', 34),
#  ('Country of Origin', 34),
#  ('Sampling Point', 34),
#  ('Address', 34),
#  ('Brand Name', 34),
#  ('Packer / Manufacturer / Importer', 34),
#  ('Pesticide residues found in mg/kg (MRL)', 34)]

# %%
del df[None]
df.head()
# Out:
#    Sample ID     Date of Sampling                Description  \
# 0  0753/2022  2022-09-15T00:00:00      Rooster Ware Potatoes
# 1  0941/2022  2022-08-24T00:00:00           Sagitta Potatoes
# 2  0940/2022  2022-09-07T00:00:00           Lanomma Potatoes
# 3  1077/2022  2022-09-12T00:00:00   Challenger Ware Potatoes
# 4  0793/2022  2022-09-06T00:00:00  Marfona Unwashed Potatoes
#
#   Country of Origin                Sampling Point  \
# 0                UK  Albert Bartlett Potatoes Ltd
# 1                UK                   ARG Garrett
# 2                UK          Burgess Farm Produce
# 3                UK            Lamb Weston Meijer
# 4                UK                Mack Wholesale
#
#                                       Address    Brand Name  \
# 0       Kirton Holme, Kirton. Boston PE20 1TT  None stated
# 1                   New College Farm PE33 9AZ  None stated
# 2  East Bank Sutton Bridge, Spalding PE12 9YB  None stated
# 3            Weasenham Lane, Wisbech PE13 2RN  None stated
# 4        40 Oriana Way, Southhampton SO16 0YU  None stated
#
#                     Packer / Manufacturer / Importer  \
# 0
# 1    Bradmount Foods 14 Dessert Martin Road BT45 7RB
# 2                             Robert Davies Wisbech
# 3                                     Scott Newman
# 4  PK Farms Willowdene Farm, Armstrong Lane, Bost...
#
#   Pesticide residues found in mg/kg (MRL)
# 0     None were detected above the set RL
# 1     None were detected above the set RL
# 2     None were detected above the set RL
# 3             fluopyram 0.01 (MRL = 0.15)
# 4     None were detected above the set RL

# %%
df.describe()
# Out:
#         Sample ID     Date of Sampling       Description Country of Origin  \
# count          10                   10                10                10
# unique         10                    9                 8                 2
# top     0940/2022  2022-08-31T00:00:00  Sagitta Potatoes                UK
# freq            1                    2                 2                 9
#
#         Sampling Point                               Address    Brand Name  \
# count               10                                    10            10
# unique              10                                    10             1
# top     Mack Wholesale  40 Oriana Way, Southhampton SO16 0YU  None stated
# freq                 1                                     1            10
#
#        Packer / Manufacturer / Importer  \
# count                                10
# unique                               10
# top                          KP Crisps
# freq                                  1
#
#        Pesticide residues found in mg/kg (MRL)
# count                                       10
# unique                                       4
# top        None were detected above the set RL
# freq                                         6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Sample ID                                10 non-null     object
#  1   Date of Sampling                         10 non-null     object
#  2   Description                              10 non-null     object
#  3   Country of Origin                        10 non-null     object
#  4   Sampling Point                           10 non-null     object
#  5   Address                                  10 non-null     object
#  6   Brand Name                               10 non-null     object
#  7   Packer / Manufacturer / Importer         10 non-null     object
#  8   Pesticide residues found in mg/kg (MRL)  10 non-null     object
#  9   None                                     0 non-null      object
# dtypes: object(10)
# memory usage: 1008.0+ bytes

# %%
list(df)
# Out:
# ['Sample ID',
#  'Date of Sampling',
#  'Description',
#  'Country of Origin',
#  'Sampling Point',
#  'Address',
#  'Brand Name',
#  'Packer / Manufacturer / Importer',
#  'Pesticide residues found in mg/kg (MRL)',
#  None]

# %%
def modify_df(df):
    
    # remove null column at end
    del df[None]
    # fill na values
    df.fillna(method='ffill', inplace=True)
    
     
def extract_pcode(df,col):  
    regexp = r'([A-Za-z]*[0-9]*\s[0-9]*[A-Za-z]*$)'
    
    df[col+'_post_code']=df[col].str.extract(regexp)
    return df
    
def extract_pesticide(df):
    
    df.replace({'None were detected above the set RL': 'n/a'}, regex=True, inplace=True)
    
    df2=df['pesticide_residues_found_in_mg/kg_(mrl)'].str.extract(r'(.*)\s(\d[\d.]*)\s+\(MRL\s*=\s*(\d[\d.]*)\)')

    df2.fillna(0, inplace=True)
    
    df2.rename(columns={0:'chem_name',1:'amount_detected',2:'mrl'},inplace=True)
   
    
    return df2
    
    
def rename_cols(df):
    renaming_dict = {
    old_name : new_name 
        for old_name,new_name 
        in zip(list(df),[new_name.lower().replace(' ','_') 
                         for new_name in list(df)])
    }

    df = df.rename(columns=renaming_dict)
    return df

# %%
# Out:
# Index(['Sample ID', 'Date of Sampling', 'Description', 'Country of Origin',
#        'Sampling Point', 'Address', 'Brand Name',
#        'Packer / Manufacturer / Importer',
#        'Pesticide residues found in mg/kg (MRL)'],
#       dtype='object')

# %%
# # df['Address'][0].str.extract(r')
# test_add = df['Address'][0]
# print(test_add)
# import re

# regexp = r'([A-Za-z]*[0-9]*\s[0-9]*[A-Za-z]*$)'
# re.search(regexp, test_add)

# print(df.Address.head(10))

# dfpcode=df.Address.str.extract(regexp)

# len(df), len(dfpcode)

# %%
# 

# df2
# Out:
#     level_0  index             Sample ID     Date of Sampling  \
# 0         0      0  Dwarf Beans                          None
# 1         1      1            2704/2022           20/09/2022
# 2         2      2   Fine Beans                   20/09/2022
# 3         3      3            2045/2022           20/09/2022
# 4         4      4            2701/2022           20/09/2022
# ..      ...    ...                   ...                  ...
# 68       68      6             0792/2022  2022-09-08T00:00:00
# 69       69      7             0765/2022  2022-09-14T00:00:00
# 70       70      8             0938/2022  2022-09-01T00:00:00
# 71       71      9             0833/2022  2022-08-31T00:00:00
# 72       72     10             0833/2022  2022-08-31T00:00:00
#
#                   Description Country of Origin  \
# 0                        None              None
# 1                Dwarf Beans                UK
# 2                Dwarf Beans                UK
# 3         Trimmed Fine Beans             Kenya
# 4           Extra Fine Beans             Kenya
# ..                        ...               ...
# 68  Marfona Unwashed Potatoes                UK
# 69           Sagitta Potatoes                UK
# 70      Marfona Ware Potatoes                UK
# 71               Lady Rosetta      England (UK)
# 72               Lady Rosetta      England (UK)
#
#                    Sampling Point  \
# 0                            None
# 1   WM Morrison Supermarkets PLC
# 2   WM Morrison Supermarkets PLC
# 3                           Asda
# 4                          Tesco
# ..                            ...
# 68               Stoke Fruit Farm
# 69             Total Produce Ltd.
# 70         Tulipland Potatoes Ltd
# 71                Tyrrells Crisps
# 72                Tyrrells Crisps
#
#                                               Address      Brand Name  \
# 0                                                None            None
# 1   Dorcan House Site, Eldene Drive, Swindon SN3 3TX      Morrisons
# 2   Dorcan House Site, Eldene Drive, Swindon SN3 3TX      Morrisons
# 3             Highweek Street, Newton Abbot TQ12 1TG           Asda
# 4          Askham Bar, Tadcaster Road, York YO24 1LW   Tesco Finest
# ..                                                ...             ...
# 68  77 Havant Road, Hayling Island, Hampshire PO11...    None stated
# 69  Callywith Gate Industrial Estate, Launceston R...    None stated
# 70                   Fengate, Moulton Chapel PE12 0XL    None stated
# 71  Tyrrells Court, Stretford Bridge, Leominster H...    None stated
# 72  Tyrrells Court, Stretford Bridge, Leominster H...    None stated
#
#                      Packer / Manufacturer / Importer  \
# 0                                                None
# 1   Wm Morrisons Supermarkets PLC 71 Gain Lane, Br...
# 2   Wm Morrisons Supermarkets PLC 71 Gain Lane, Br...
# 3   ASDA Stores Ltd Great Wilson Street, Leeds LS1...
# 4   Tesco Stores Ltd Tesco House, Shire Park, Kest...
# ..                                                ...
# 68  Stoke Fruit Farm 77 Havant Road, Hayling Islan...
# 69       CS Duston & Son Colwith Farm, Par, Cornwall
# 70                                 Garden of Elveden
# 71                                         KP Crisps
# 72                                         KP Crisps
#
#    Pesticide residues found in mg/kg (MRL)         chem_name amount_detected  \
# 0                                     None                 0               0
# 1     None were detected above the set RL                  0               0
# 2     None were detected above the set RL                  0               0
# 3     None were detected above the set RL                  0               0
# 4       cyantraniliprole 0.04 (MRL = 1.5)   cyantraniliprole            0.04
# ..                                     ...               ...             ...
# 68         maleic hydrazide 7.7 (MRL = 60)  maleic hydrazide             7.7
# 69          maleic hydrazide 17 (MRL = 60)  maleic hydrazide              17
# 70     None were detected above the set RL                 0               0
# 71     None were detected above the set RL                 0               0
# 72     None were detected above the set RL                 0               0
#
#     mrl
# 0     0
# 1     0
# 2     0
# 3     0
# 4   1.5
# ..  ...
# 68   60
# 69   60
# 70    0
# 71    0
# 72    0
#
# [73 rows x 14 columns]

# %%
from modify_dfs import *

df2 = rename_cols(df)
df2 = extract_pesticide(df2)
df2
# Out:
#            chem_name amount_detected  mrl
# 0                  0               0    0
# 1                  0               0    0
# 2                  0               0    0
# 3                  0               0    0
# 4   cyantraniliprole            0.04  1.5
# ..               ...             ...  ...
# 68  maleic hydrazide             7.7   60
# 69  maleic hydrazide              17   60
# 70                 0               0    0
# 71                 0               0    0
# 72                 0               0    0
#
# [73 rows x 3 columns]

# %%
df2 = extract_pcode(df,'Address')
df2.head()
# Out:
#    Sample ID     Date of Sampling                Description  \
# 0  0753/2022  2022-09-15T00:00:00      Rooster Ware Potatoes
# 1  0941/2022  2022-08-24T00:00:00           Sagitta Potatoes
# 2  0940/2022  2022-09-07T00:00:00           Lanomma Potatoes
# 3  1077/2022  2022-09-12T00:00:00   Challenger Ware Potatoes
# 4  0793/2022  2022-09-06T00:00:00  Marfona Unwashed Potatoes
#
#   Country of Origin                Sampling Point  \
# 0                UK  Albert Bartlett Potatoes Ltd
# 1                UK                   ARG Garrett
# 2                UK          Burgess Farm Produce
# 3                UK            Lamb Weston Meijer
# 4                UK                Mack Wholesale
#
#                                       Address    Brand Name  \
# 0       Kirton Holme, Kirton. Boston PE20 1TT  None stated
# 1                   New College Farm PE33 9AZ  None stated
# 2  East Bank Sutton Bridge, Spalding PE12 9YB  None stated
# 3            Weasenham Lane, Wisbech PE13 2RN  None stated
# 4        40 Oriana Way, Southhampton SO16 0YU  None stated
#
#                     Packer / Manufacturer / Importer  \
# 0
# 1    Bradmount Foods 14 Dessert Martin Road BT45 7RB
# 2                             Robert Davies Wisbech
# 3                                     Scott Newman
# 4  PK Farms Willowdene Farm, Armstrong Lane, Bost...
#
#   Pesticide residues found in mg/kg (MRL) Address_post_code
# 0     None were detected above the set RL          PE20 1TT
# 1     None were detected above the set RL          PE33 9AZ
# 2     None were detected above the set RL          PE12 9YB
# 3             fluopyram 0.01 (MRL = 0.15)          PE13 2RN
# 4     None were detected above the set RL          SO16 0YU
